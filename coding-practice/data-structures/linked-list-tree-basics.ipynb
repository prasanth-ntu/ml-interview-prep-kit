# %% [markdown]
# # GeeksforGeeks - Linked List

# %% [markdown]
# References
# - [1] https://www.geeksforgeeks.org/data-structures/linked-list/ - Contains 25 topics on linked list

# %% [markdown]
# ## Introduction to Linked List

# %% [markdown]
# ![https://media.geeksforgeeks.org/wp-content/cdn-uploads/gq/2013/03/Linkedlist.png](https://media.geeksforgeeks.org/wp-content/cdn-uploads/gq/2013/03/Linkedlist.png)

# %%
class Node:
    def __init__(self, data):
        self.data = data 
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
# Start with a empty list
llist = LinkedList()

# We create 3 nodes
llist.head = Node(1)
second = Node(2)
third = Node(3)

# Let's link the nodes
llist.head.next = second # Link the first node with second
second.next = third # Link the second node with third

llist.traversal()
# Out:
# 1
# 2
# 3

# %% [markdown]
# Reference
# - [1] https://www.geeksforgeeks.org/linked-list-set-1-introduction/

# %% [markdown]
# ## Inserting a node

# %% [markdown]
# A node can be added in 3 ways
# - At the front of the linked list
# - After a given node
# - At the end of the linked list
#
# ![At the front of the linked list](https://media.geeksforgeeks.org/wp-content/cdn-uploads/gq/2013/03/Linkedlist_insert_at_start.png)
# ![Add a node after a given node](https://media.geeksforgeeks.org/wp-content/cdn-uploads/gq/2013/03/Linkedlist_insert_middle.png)
# ![Append new node at the end](https://media.geeksforgeeks.org/wp-content/cdn-uploads/gq/2013/03/Linkedlist_insert_last.png)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
    
    
llist = LinkedList()
llist.append(6) #6
llist.push(7) #7,6
llist.push(1); #1,7,6
llist.append(4) #1,7,6,4
llist.insert_after(llist.head.next, 8) # 1,7,8,6,4

llist.traversal()
# Out:
# 1
# 7
# 8
# 6
# 4

# %% [markdown]
# Reference
# - [1] https://www.geeksforgeeks.org/linked-list-set-2-inserting-a-node/

# %% [markdown]
# ## Deleting a node (using key => data)

# %% [markdown]
# ![Deleting a node](https://media.geeksforgeeks.org/wp-content/cdn-uploads/gq/2014/05/Linkedlist_deletion.png)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
        
        
    
    
llist = LinkedList()
llist.traversal()

llist.append(6) #6
llist.push(7) #7,6
llist.push(1); #1,7,6
llist.append(4) #1,7,6,4
llist.insert_after(llist.head.next, 8) # 1,7,8,6,4

print ('After all node appending, pushing and inserting')
llist.traversal()

llist.delete_node(1) # 7,8,6,4
llist.delete_node(6) # 7,8,4
llist.delete_node(4) # 7,8
llist.delete_node(0) # 7,8

print ('After performing all deletions')
llist.traversal()
# Out:
# After all node appending, pushing and inserting
# 1
# 7
# 8
# 6
# 4
# Key 0 doesn't exist in Linked List
# After performing all deletions
# 7
# 8

# %%
llist = LinkedList()
llist.push(7)
llist.push(1)
llist.push(3)
llist.push(2)

print ("Created Linked List: ")
llist.traversal()
llist.delete_node(1)
print ("\nLinked List after Deletion of 1:")
llist.traversal()
# Out:
# Created Linked List:
# 2
# 3
# 1
# 7
#
# Linked List after Deletion of 1:
# 2
# 3
# 7

# %% [markdown]
# Reference
#
# [1] https://www.geeksforgeeks.org/linked-list-set-3-deleting-node/

# %% [markdown]
# ## Delete a Linked List node at a given position

# %% [markdown]
# ```
# Input: position = 1, Linked List = 8->2->3->1->7
# Output: Linked List =  8->3->1->7
#
# Input: position = 0, Linked List = 8->2->3->1->7
# Output: Linked List = 2->3->1->7
# ```

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
    # If the linked list has a node at given index loc, delete it 
    def delete_node_at_index(self, index):
        # edge cases
        if self.head is None:
            print ('Empty Linked List, nothing to delete')
            return
        if index == 0:
            self.head= self.head.next
            return
        else:
            temp = self.head
            index_counter = 0
            while temp.next:
                index_counter+=1
                if index_counter==index:
                    temp.next = temp.next.next
                    return
        print ("Index {} does't exist in Linked List".format(index))
        
        
    
    
llist = LinkedList()
llist.append(8)
llist.append(2)
llist.append(3)
llist.append(1)
llist.append(7) # 8,2,3,1,7
print ('After all node appending')
llist.traversal()
llist.delete_node_at_index(1)
print ('After performing all deletions')
llist.traversal()

llist = LinkedList()
llist.append(8)
llist.append(2)
llist.append(3)
llist.append(1)
llist.append(7) # 8,2,3,1,7
print ('After all node appending')
llist.traversal()
llist.delete_node_at_index(0)
print ('After performing all deletions')
llist.traversal()
# Out:
# After all node appending
# 8
# 2
# 3
# 1
# 7
# After performing all deletions
# 8
# 3
# 1
# 7
# After all node appending
# 8
# 2
# 3
# 1
# 7
# After performing all deletions
# 2
# 3
# 1
# 7

# %% [markdown]
# Reference
# - [1] https://www.geeksforgeeks.org/delete-a-linked-list-node-at-a-given-position/

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
    # If the linked list has a node at given index loc, delete it 
    def delete_node_at_index(self, index):
        # edge cases
        if self.head is None:
            print ('Empty Linked List, nothing to delete')
            return
        if index == 0:
            self.head= self.head.next
            return
        else:
            temp = self.head
            index_counter = 0
            while temp.next:
                index_counter+=1
                if index_counter==index:
                    temp.next = temp.next.next
                    return
        print ("Index {} does't exist in Linked List".format(index))
        
    # In python, garbage collection happens automatically
    def delete_linked_list(self):
        self.head=None
        
llist = LinkedList()       
llist.push(1)
llist.push(4)
llist.push(1)
llist.push(12)
llist.push(1)
print("Before deleting linked list")
llist.traversal()

llist.delete_linked_list()
print("After deleting linked list")
llist.traversal()
# Out:
# Before deleting linked list
# 1
# 12
# 1
# 4
# 1
# After deleting linked list

# %% [markdown]
# ## Find length of a linked list (iterative)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
    # If the linked list has a node at given index loc, delete it 
    def delete_node_at_index(self, index):
        # edge cases
        if self.head is None:
            print ('Empty Linked List, nothing to delete')
            return
        if index == 0:
            self.head= self.head.next
            return
        else:
            temp = self.head
            index_counter = 0
            while temp.next:
                index_counter+=1
                if index_counter==index:
                    temp.next = temp.next.next
                    return
        print ("Index {} does't exist in Linked List".format(index))
        
    # In python, garbage collection happens automatically
    def delete_linked_list(self):
        self.head=None
        
    def length(self):
        if self.head is None:
            return 0
        else:
            counter = 1
            temp = self.head
            while temp.next:
                counter += 1
                temp = temp.next
            return counter
        
llist = LinkedList()       
llist.push(1)
llist.push(4)
llist.push(1)
llist.push(12)
llist.push(1)
llist.traversal()
print ("Length of linked list:", llist.length())
# Out:
# 1
# 12
# 1
# 4
# 1
# Length of linked list: 5

# %% [markdown]
# References:
# - [1] https://www.geeksforgeeks.org/find-length-of-a-linked-list-iterative-and-recursive/

# %% [markdown]
# ## Search an element in a linked list (iterative)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
    # If the linked list has a node at given index loc, delete it 
    def delete_node_at_index(self, index):
        # edge cases
        if self.head is None:
            print ('Empty Linked List, nothing to delete')
            return
        if index == 0:
            self.head= self.head.next
            return
        else:
            temp = self.head
            index_counter = 0
            while temp.next:
                index_counter+=1
                if index_counter==index:
                    temp.next = temp.next.next
                    return
        print ("Index {} does't exist in Linked List".format(index))
        
    # In python, garbage collection happens automatically
    def delete_linked_list(self):
        self.head=None
        
    def length(self):
        if self.head is None:
            return 0
        else:
            counter = 1
            temp = self.head
            while temp.next:
                counter += 1
                temp = temp.next
            return counter
        
    def search(self, key):
        if self.head is None:
            return False
        else:
            temp = self.head
            while temp:
                if temp.data == key:
                    return True
                else:
                    temp = temp.next
            return False
        
llist = LinkedList()       
llist.push(1)
llist.push(4)
llist.push(1)
llist.push(12)
llist.push(1)
llist.traversal()

key = 12
print ("Search  linked list:", llist.search(key))
# Out:
# 1
# 12
# 1
# 4
# 1
# Search  linked list: True

# %% [markdown]
# References
# - [1] https://www.geeksforgeeks.org/search-an-element-in-a-linked-list-iterative-and-recursive/

# %% [markdown]
# ## Get Nth node in a linked list

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
    # If the linked list has a node at given index loc, delete it 
    def delete_node_at_index(self, index):
        # edge cases
        if self.head is None:
            print ('Empty Linked List, nothing to delete')
            return
        if index == 0:
            self.head= self.head.next
            return
        else:
            temp = self.head
            index_counter = 0
            while temp.next:
                index_counter+=1
                if index_counter==index:
                    temp.next = temp.next.next
                    return
        print ("Index {} does't exist in Linked List".format(index))
        
    # In python, garbage collection happens automatically
    def delete_linked_list(self):
        self.head=None
        
    def length(self):
        if self.head is None:
            return 0
        else:
            counter = 1
            temp = self.head
            while temp.next:
                counter += 1
                temp = temp.next
            return counter
        
    def search(self, key):
        if self.head is None:
            return False
        else:
            temp = self.head
            while temp:
                if temp.data == key:
                    return True
                else:
                    temp = temp.next
            return False
        
    def get_nth_node(self, n):
        if self.head is None:
            return None
        else:
            if n==0:
                return self.head.data
            else:
                temp = self.head
                counter = 0
                while temp.next:
                    counter += 1
                    temp = temp.next
                    if counter == n:
                        return temp.data
            return None
            
        
llist = LinkedList()       
llist.push(1)
llist.push(4)
llist.push(1)
llist.push(12)
llist.push(1)
llist.traversal()

i = 5
print ("Get Nth element from linked list:", llist.get_nth_node(i))
# Out:
# 1
# 12
# 1
# 4
# 1
# Get Nth element from linked list: None

# %% [markdown]
# References
# - [1] https://www.geeksforgeeks.org/write-a-function-to-get-nth-node-in-a-linked-list/

# %% [markdown]
# ## Get Nth node from end of linked list

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
    # If the linked list has a node at given index loc, delete it 
    def delete_node_at_index(self, index):
        # edge cases
        if self.head is None:
            print ('Empty Linked List, nothing to delete')
            return
        if index == 0:
            self.head= self.head.next
            return
        else:
            temp = self.head
            index_counter = 0
            while temp.next:
                index_counter+=1
                if index_counter==index:
                    temp.next = temp.next.next
                    return
        print ("Index {} does't exist in Linked List".format(index))
        
    # In python, garbage collection happens automatically
    def delete_linked_list(self):
        self.head=None
        
    def length(self):
        if self.head is None:
            return 0
        else:
            counter = 1
            temp = self.head
            while temp.next:
                counter += 1
                temp = temp.next
            return counter
        
    def search(self, key):
        if self.head is None:
            return False
        else:
            temp = self.head
            while temp:
                if temp.data == key:
                    return True
                else:
                    temp = temp.next
            return False
        
    def get_nth_node(self, n):
        if self.head is None:
            return None
        else:
            if n==0:
                return self.head.data
            else:
                temp = self.head
                counter = 0
                while temp.next:
                    counter += 1
                    temp = temp.next
                    if counter == n:
                        return temp.data
            return None
        
    def get_nth_node_from_end(self, n):
        if n <= 0:
            return None
        if self.head is None:
            return None
        else:
            ll_data=[]
            temp = self.head
            while temp:
                ll_data.append(temp.data)
                temp = temp.next
            if n <= len(ll_data):
                return ll_data[-n]
            else:
                return None
            
    def get_nth_node_from_end_v2(self,n):
        length_of_llist = self.length()
        return self.get_nth_node(length_of_llist-n)
        
llist = LinkedList()       
llist.push(1)
llist.push(4)
llist.push(1)
llist.push(12)
llist.push(1)
llist.traversal()

i = 0
print ("Get Nth = [{}]th element from end of linked list   : {}".format(i, llist.get_nth_node_from_end(i)))
print ("Get Nth = [{}]th element from end of linked list v2: {}".format(i, llist.get_nth_node_from_end_v2(i)))
# Out:
# 1
# 12
# 1
# 4
# 1
# Get Nth = [0]th element from end of linked list   : None
# Get Nth = [0]th element from end of linked list v2: None

# %% [markdown]
# References
# - [1] https://www.geeksforgeeks.org/nth-node-from-the-end-of-a-linked-list/

# %% [markdown]
# ## Get the middle of the linked list

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
    # If the linked list has a node at given index loc, delete it 
    def delete_node_at_index(self, index):
        # edge cases
        if self.head is None:
            print ('Empty Linked List, nothing to delete')
            return
        if index == 0:
            self.head= self.head.next
            return
        else:
            temp = self.head
            index_counter = 0
            while temp.next:
                index_counter+=1
                if index_counter==index:
                    temp.next = temp.next.next
                    return
        print ("Index {} does't exist in Linked List".format(index))
        
    # In python, garbage collection happens automatically
    def delete_linked_list(self):
        self.head=None
        
    def length(self):
        if self.head is None:
            return 0
        else:
            counter = 1
            temp = self.head
            while temp.next:
                counter += 1
                temp = temp.next
            return counter
        
    def search(self, key):
        if self.head is None:
            return False
        else:
            temp = self.head
            while temp:
                if temp.data == key:
                    return True
                else:
                    temp = temp.next
            return False
        
    def get_nth_node(self, n):
        if self.head is None:
            return None
        else:
            if n==0:
                return self.head.data
            else:
                temp = self.head
                counter = 0
                while temp.next:
                    counter += 1
                    temp = temp.next
                    if counter == n:
                        return temp.data
            return None
        
    def get_nth_node_from_end(self, n):
        if n <= 0:
            return None
        if self.head is None:
            return None
        else:
            ll_data=[]
            temp = self.head
            while temp:
                ll_data.append(temp.data)
                temp = temp.next
            if n <= len(ll_data):
                return ll_data[-n]
            else:
                return None
            
    def get_nth_node_from_end_v2(self,n):
        length_of_llist = self.length()
        return self.get_nth_node(length_of_llist-n)
    
    def get_middle_data(self):
        # Edge case: Empty linked list
        if self.head is None:
            return None 

        length_of_llist = self.length()
        
        # Even no of elements element in linked list
        if length_of_llist %2==0:
            return self.get_nth_node(length_of_llist//2)
        else:
            return self.get_nth_node(length_of_llist//2)
        # More than 1 element in linked list
        
        
llist = LinkedList()       
# llist.push(1)
# llist.push(4)
# llist.push(1)
# llist.push(12)
# llist.push(1)

for i in range(5, 0, -1):
    llist.push(i)
    llist.traversal()

    print ("Get middle element from end of linked list   : {}".format(llist.get_middle_data()))
# Out:
# 5
# Get middle element from end of linked list   : 5
# 4
# 5
# Get middle element from end of linked list   : 5
# 3
# 4
# 5
# Get middle element from end of linked list   : 4
# 2
# 3
# 4
# 5
# Get middle element from end of linked list   : 4
# 1
# 2
# 3
# 4
# 5
# Get middle element from end of linked list   : 3

# %% [markdown]
# References
# - [1] https://www.geeksforgeeks.org/write-a-c-function-to-print-the-middle-of-the-linked-list/

# %% [markdown]
# ## Detect loop in a list

# %% [markdown]
# ## Detect and count loop in a list

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
    # If the linked list has a node at given index loc, delete it 
    def delete_node_at_index(self, index):
        # edge cases
        if self.head is None:
            print ('Empty Linked List, nothing to delete')
            return
        if index == 0:
            self.head= self.head.next
            return
        else:
            temp = self.head
            index_counter = 0
            while temp.next:
                index_counter+=1
                if index_counter==index:
                    temp.next = temp.next.next
                    return
        print ("Index {} does't exist in Linked List".format(index))
        
    # In python, garbage collection happens automatically
    def delete_linked_list(self):
        self.head=None
        
    def length(self):
        if self.head is None:
            return 0
        else:
            counter = 1
            temp = self.head
            while temp.next:
                counter += 1
                temp = temp.next
            return counter
        
    def search(self, key):
        if self.head is None:
            return False
        else:
            temp = self.head
            while temp:
                if temp.data == key:
                    return True
                else:
                    temp = temp.next
            return False
        
    def get_nth_node(self, n):
        if self.head is None:
            return None
        else:
            if n==0:
                return self.head.data
            else:
                temp = self.head
                counter = 0
                while temp.next:
                    counter += 1
                    temp = temp.next
                    if counter == n:
                        return temp.data
            return None
        
    def get_nth_node_from_end(self, n):
        if n <= 0:
            return None
        if self.head is None:
            return None
        else:
            ll_data=[]
            temp = self.head
            while temp:
                ll_data.append(temp.data)
                temp = temp.next
            if n <= len(ll_data):
                return ll_data[-n]
            else:
                return None
            
    def get_nth_node_from_end_v2(self,n):
        length_of_llist = self.length()
        return self.get_nth_node(length_of_llist-n)
    
    def get_middle_data(self):
        # Edge case: Empty linked list
        if self.head is None:
            return None 

        length_of_llist = self.length()
        
        # Even no of elements element in linked list
        if length_of_llist %2==0:
            return self.get_nth_node(length_of_llist//2)
        else:
            return self.get_nth_node(length_of_llist//2)
        # More than 1 element in linked list

    def detect_loop(self):
        if self.head is None:
            return None
        
        ids_list = []
        temp = llist.head
        while temp:
            temp_id = id(temp)
            if temp_id not in ids_list:
                ids_list.append(temp_id)
                temp = temp.next
            else:
                return True # Loop exists
            
        return False # Loop does not exist
    
    def detect_loop_v2(self):
        if self.head is None:
            return None
        
        nodes_set = set()
        temp = llist.head
        while temp:
            if temp not in nodes_set:
                nodes_set.add(temp)
                temp = temp.next
            else:
                return True # Loop exists
            
        return False # Loop does not exist
            
    def detect_and_count_loop_v2(self):
        if self.head is None:
            return None
        
        nodes_set = set()
        temp = llist.head
        while temp:
            if temp not in nodes_set:
                nodes_set.add(temp)
                temp = temp.next
            else:
                return len(nodes_set) # Loop exists
            
        return 0 # Loop does not exist
    
llist = LinkedList()
# head = None;

llist.push(20);
llist.push(4);
llist.push(15);
llist.push(10);

''' Create a loop for testing '''
llist.head.next.next.next.next = llist.head;

print ("Detect Loop    :", llist.detect_loop())
print ("Detect Loop  v2:", llist.detect_loop_v2())
print ("Detect and Count Loop Loop  v2:", llist.detect_and_count_loop_v2())
# Out:
# Detect Loop    : True
# Detect Loop  v2: True
# Detect and Count Loop Loop  v2: 4

# %% [markdown]
# References
# - [1] https://www.geeksforgeeks.org/detect-loop-in-a-linked-list/
# - [2] https://www.geeksforgeeks.org/find-length-of-loop-in-linked-list/

# %% [markdown]
# ## Check if a linked list is palindrome

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    # Push new node at the front
    def push(self, data):
        new_node = Node(data)
        
        new_node.next = self.head
        
        self.head = new_node
        
    # Insert new node after a given node
    def insert_after(self, prev_node, new_data):
        if prev_node is None:
            print ("Given prev node must be in LinkedList")
            return 
        
        new_node = Node(new_data)

        new_node.next = prev_node.next
        
        prev_node.next = new_node
        
    # Append new node at the end
    def append(self, new_data):
        new_node = Node(new_data)
        
        if self.head is None:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
        
    def traversal(self):
        temp = self.head
        while temp:
            print (temp.data)
            temp = temp.next
        
    #  If the key matches any of the data in LinkedList, delete it
    def delete_node(self, key):
        # Edge case
        if self.head is None:
            print ('Linked List is empty')
            return
        # The key exists in the very first node
        if self.head.data == key:
            self.head = self.head.next
            return
        temp = self.head
        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            else:
                temp = temp.next
        print ("Key {} doesn't exist in Linked List".format(key))
        
    # If the linked list has a node at given index loc, delete it 
    def delete_node_at_index(self, index):
        # edge cases
        if self.head is None:
            print ('Empty Linked List, nothing to delete')
            return
        if index == 0:
            self.head= self.head.next
            return
        else:
            temp = self.head
            index_counter = 0
            while temp.next:
                index_counter+=1
                if index_counter==index:
                    temp.next = temp.next.next
                    return
        print ("Index {} does't exist in Linked List".format(index))
        
    # In python, garbage collection happens automatically
    def delete_linked_list(self):
        self.head=None
        
    def length(self):
        if self.head is None:
            return 0
        else:
            counter = 1
            temp = self.head
            while temp.next:
                counter += 1
                temp = temp.next
            return counter
        
    def search(self, key):
        if self.head is None:
            return False
        else:
            temp = self.head
            while temp:
                if temp.data == key:
                    return True
                else:
                    temp = temp.next
            return False
        
    def get_nth_node(self, n):
        if self.head is None:
            return None
        else:
            if n==0:
                return self.head.data
            else:
                temp = self.head
                counter = 0
                while temp.next:
                    counter += 1
                    temp = temp.next
                    if counter == n:
                        return temp.data
            return None
        
    def get_nth_node_from_end(self, n):
        if n <= 0:
            return None
        if self.head is None:
            return None
        else:
            ll_data=[]
            temp = self.head
            while temp:
                ll_data.append(temp.data)
                temp = temp.next
            if n <= len(ll_data):
                return ll_data[-n]
            else:
                return None
            
    def get_nth_node_from_end_v2(self,n):
        length_of_llist = self.length()
        return self.get_nth_node(length_of_llist-n)
    
    def get_middle_data(self):
        # Edge case: Empty linked list
        if self.head is None:
            return None 

        length_of_llist = self.length()
        
        # Even no of elements element in linked list
        if length_of_llist %2==0:
            return self.get_nth_node(length_of_llist//2)
        else:
            return self.get_nth_node(length_of_llist//2)
        # More than 1 element in linked list

    def detect_loop(self):
        if self.head is None:
            return None
        
        ids_list = []
        temp = llist.head
        while temp:
            temp_id = id(temp)
            if temp_id not in ids_list:
                ids_list.append(temp_id)
                temp = temp.next
            else:
                return True # Loop exists
            
        return False # Loop does not exist
    
    def detect_loop_v2(self):
        if self.head is None:
            return None
        
        nodes_set = set()
        temp = llist.head
        while temp:
            if temp not in nodes_set:
                nodes_set.add(temp)
                temp = temp.next
            else:
                return True # Loop exists
            
        return False # Loop does not exist
            
    def detect_and_count_loop_v2(self):
        if self.head is None:
            return None
        
        nodes_set = set()
        temp = llist.head
        while temp:
            if temp not in nodes_set:
                nodes_set.add(temp)
                temp = temp.next
            else:
                return len(nodes_set) # Loop exists
            
        return 0 # Loop does not exist
    
    # uses python list to store all the items in the linked list #
    def check_palindrome(self):
        if self.head is None:
            return None
        temp_list = []
        temp = self.head
        while temp:
            temp_list.append(temp.data)
            temp = temp.next
        return temp_list == temp_list[::-1]
    
llist = LinkedList()
# head = None;

llist.append('R');
llist.append('A');
llist.append('D');
llist.append('A');
# llist.append('R');
llist.traversal()

llist.check_palindrome()
# Out:
# R
# A
# D
# A
# ['R']
# ['R', 'A']
# ['R', 'A', 'D']
# ['R', 'A', 'D', 'A']
# False

# %% [markdown]
# References
# - [1] https://wwwm.geeksforgeeks.org/function-to-check-if-a-singly-linked-list-is-palindrome/

# %% [markdown]
# # Binary Tree - GeeksforGeeks

# %% [markdown]
# ## Introduction

# %%
class Node():
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key
        
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)

# %% [markdown]
# References
# - [1] https://www.geeksforgeeks.org/binary-tree-set-1-introduction/

# %% [markdown]
# ## Insertion in a Binary Tree in level order

# %%
# Python program to insert element in binary tree
class newNode():

	def __init__(self, data):
		self.key = data
		self.left = None
		self.right = None
		
""" Inorder traversal of a binary tree"""
def inorder(temp):

	if (not temp):
		return

	inorder(temp.left)
	print(temp.key,end = " ")
	inorder(temp.right)


"""function to insert element in binary tree """
def insert(temp,key):

	if not temp:
		root = newNode(key)
		return
	q = []
	q.append(temp)

	# Do level order traversal until we find
	# an empty place.
	while (len(q)):
		temp = q[0]
		q.pop(0)

		if (not temp.left):
			temp.left = newNode(key)
			break
		else:
			q.append(temp.left)

		if (not temp.right):
			temp.right = newNode(key)
			break
		else:
			q.append(temp.right)
	
# Driver code
if __name__ == '__main__':
	root = newNode(10)
	root.left = newNode(11)
	root.left.left = newNode(7)
	root.right = newNode(9)
	root.right.left = newNode(15)
	root.right.right = newNode(8)

	print("Inorder traversal before insertion:", end = " ")
	inorder(root)

	key = 12
	insert(root, key)

	print()
	print("Inorder traversal after insertion:", end = " ")
	inorder(root)

# This code is contributed by SHUBHAMSINGH10

# %% [markdown]
# References
# - [1] https://www.geeksforgeeks.org/insertion-in-a-binary-tree-in-level-order/

# %% [markdown]
# ## BFS vs DFS

# %% [markdown]
# ![https://media.geeksforgeeks.org/wp-content/cdn-uploads/2009/06/tree12.gif](https://media.geeksforgeeks.org/wp-content/cdn-uploads/2009/06/tree12.gif)

# %% [markdown]
# ```
# BFS and DFSs of above Tree
#
# Breadth First Traversal : 1 2 3 4 5 (BFS a.k.a Level Order Traversal)
#
# Depth First Traversals:
#       Preorder Traversal (Root, Left, Right) : 1 2 4 5 3
#       Inorder Traversal  (Left, Root, Right) :  4 2 5 1 3
#       Postorder Traversal (Left, Right, Root): 4 5 2 3 1
# ```

# %% [markdown]
# ![https://i.ytimg.com/vi/WLvU5EQVZqY/maxresdefault.jpg](https://i.ytimg.com/vi/WLvU5EQVZqY/maxresdefault.jpg)

# %% [markdown]
# Reference
# - [1] https://www.geeksforgeeks.org/bfs-vs-dfs-binary-tree/

# %% [markdown]
# ### BFS

# %% [markdown]
# ![https://media.geeksforgeeks.org/wp-content/cdn-uploads/level_order_traversal.png](https://media.geeksforgeeks.org/wp-content/cdn-uploads/level_order_traversal.png)
#
# Level order traversal of the above tree is 1 2 3 4 5

# %% [markdown]
# #### Method 2 (Using queue)
#
# Algorithm:
# For each node, first the node is visited and then it’s child nodes are put in a FIFO queue.
#
# printLevelorder(tree)
# ```
# 1) Create an empty queue q
# 2) temp_node = root /*start from root*/
# 3) Loop while temp_node is not NULL
#     a) print temp_node->data.
#     b) Enqueue temp_node’s children
#       (first left then right children) to q
#     c) Dequeue a node from q.
# ```

# %%
# Python program to print level
# order traversal using Queue

# A node structure
class Node:
	# A utility function to create a new node
	def __init__(self ,key):
		self.data = key
		self.left = None
		self.right = None

# Iterative Method to print the
# height of a binary tree
def printLevelOrder(root):
	# Base Case
	if root is None:
		return
	
	# Create an empty queue
	# for level order traversal
	queue = []

	# Enqueue Root and initialize height
	queue.append(root)

	while(len(queue) > 0):
	
		# Print front of queue and
		# remove it from queue
		print (queue[0].data)
		node = queue.pop(0)

		#Enqueue left child
		if node.left is not None:
			queue.append(node.left)

		# Enqueue right child
		if node.right is not None:
			queue.append(node.right)

#Driver Program to test above function
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

print ("Level Order Traversal of binary tree is -")
printLevelOrder(root)
#This code is contributed by Nikhil Kumar Singh(nickzuck_007)
# Out:
# Level Order Traversal of binary tree is -
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Reference
# - [1] https://www.geeksforgeeks.org/level-order-tree-traversal/

# %% [markdown]
# ### DFS

# %% [markdown]
# ![https://media.geeksforgeeks.org/wp-content/cdn-uploads/2009/06/tree12.gif](https://media.geeksforgeeks.org/wp-content/cdn-uploads/2009/06/tree12.gif)

# %% [markdown]
# Depth First Traversals:
# - (a) Inorder (Left, Root, Right) : 4 2 5 1 3
# - (b) Preorder (Root, Left, Right) : 1 2 4 5 3
# - (c) Postorder (Left, Right, Root) : 4 5 2 3 1
#
# Breadth First or Level Order Traversal : 1 2 3 4 5

# %% [markdown]
# ```
# Algorithm Inorder(tree)
#    1. Traverse the left subtree, i.e., call Inorder(left-subtree)
#    2. Visit the root.
#    3. Traverse the right subtree, i.e., call Inorder(right-subtree)
# ```

# %% [markdown]
# ```
# Algorithm Preorder(tree)
#    1. Visit the root.
#    2. Traverse the left subtree, i.e., call Preorder(left-subtree)
#    3. Traverse the right subtree, i.e., call Preorder(right-subtree)
# ```

# %% [markdown]
# ```
# Algorithm Postorder(tree)
#    1. Traverse the left subtree, i.e., call Postorder(left-subtree)
#    2. Traverse the right subtree, i.e., call Postorder(right-subtree)
#    3. Visit the root.
# ```

# %%
# Python program to for tree traversals

# A class that represents an individual node in a
# Binary Tree


class Node:
	def __init__(self, key):
		self.left = None
		self.right = None
		self.val = key


# A function to do inorder tree traversal
def printInorder(root):

	if root:

		# First recur on left child
		printInorder(root.left)

		# then print the data of node
		print(root.val),

		# now recur on right child
		printInorder(root.right)


# A function to do postorder tree traversal
def printPostorder(root):

	if root:

		# First recur on left child
		printPostorder(root.left)

		# the recur on right child
		printPostorder(root.right)

		# now print the data of node
		print(root.val),


# A function to do preorder tree traversal
def printPreorder(root):

	if root:

		# First print the data of node
		print(root.val),

		# Then recur on left child
		printPreorder(root.left)

		# Finally recur on right child
		printPreorder(root.right)


# Driver code
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
print ("Preorder traversal of binary tree is")
printPreorder(root)

print ("\nInorder traversal of binary tree is")
printInorder(root)

print ("\nPostorder traversal of binary tree is")
printPostorder(root)
# Out:
# Preorder traversal of binary tree is
# 1
# 2
# 4
# 5
# 3
#
# Inorder traversal of binary tree is
# 4
# 2
# 5
# 1
# 3
#
# Postorder traversal of binary tree is
# 4
# 5
# 2
# 3
# 1

# %% [markdown]
# Reference [1]
# - https://www.geeksforgeeks.org/tree-traversals-inorder-preorder-and-postorder/

# %% [markdown]
# # Binary Search Tree - Geek for Geek

# %% [markdown]
# # Graph Data Structure and Algorithms - GeeksforGeeks

# %% [markdown]
# https://www.geeksforgeeks.org/graph-data-structure-and-algorithms/
#
# https://www.python-course.eu/graphs_python.php
